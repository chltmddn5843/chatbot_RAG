# %%
pip install sqlalchemy pymysql pandas
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 24.0 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
# ...

# %% [markdown]
# ### 표 형식 라이브러리

# %%
pip install tabulate
# Out:
# ...
#
# ...

# %% [markdown]
# # 가독성

# %%
import pandas as pd
# 한글 출력 시 정렬 깨짐 방지
pd.set_option('display.unicode.east_asian_width', True)

# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib.parse
from tabulate import tabulate

# 1. 접속 정보 설정
DB_HOST = "192.168.5.102"
DB_PORT = "3306"
DB_USER = "ktoa"
DB_PASSWORD = "ktoa#1234"
DB_NAME = "telecom_media" 

# 2. 특수문자 처리
safe_password = urllib.parse.quote_plus(DB_PASSWORD)

# 3. SQLAlchemy Engine 생성
# 형식: mysql+pymysql://user:password@host:port/database
connection_url = f"mysql+pymysql://{DB_USER}:{safe_password}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(connection_url)

# 여러 줄 쿼리는 반드시 큰따옴표 3개를 사용하세요
query = """
select PRC_PLN_NM, COMP, NW_TYPE,BASE_PRICE, DATA_PRVD,DATA_CHARG_PLN,VOICE_PRVD, VOICE_CHARG_PLN,SUBS_COND,TGT_CUST,
	OTT_COMB_NM, OTT_COMB_PRD, OTT_COMB_MTHD,AI_SHORT_DESC
from telecom_media.mpr_pln_info
where comp = 'KT'
"""

try:
    df = pd.read_sql(query, engine)
    print(tabulate(df.head(10), headers='keys', tablefmt='psql'))
    
except Exception as e:
    print(f"쿼리 실행 에러: {e}")
# Out:
# +----+---------------+--------+-----------+--------------+-------------+------------------+--------------+-------------------+-------------+------------+---------------+----------------+-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    | PRC_PLN_NM    | COMP   | NW_TYPE   |   BASE_PRICE |   DATA_PRVD | DATA_CHARG_PLN   |   VOICE_PRVD | VOICE_CHARG_PLN   | SUBS_COND   | TGT_CUST   | OTT_COMB_NM   | OTT_COMB_PRD   | OTT_COMB_MTHD   | AI_SHORT_DESC                                                                                                                                                 |
# ...

# %%
df.head(2)
# Out:
#   PRC_PLN_NM COMP NW_TYPE  BASE_PRICE  DATA_PRVD DATA_CHARG_PLN  VOICE_PRVD  \
# 0     Y 슬림   KT      5G       55000      14336       속도제한      999999
# 1     5G Y틴   KT      5G       47000      10240       속도제한      999999
#
#   VOICE_CHARG_PLN SUBS_COND TGT_CUST OTT_COMB_NM OTT_COMB_PRD OTT_COMB_MTHD  \
# 0          무제한      0~34     청년        None         None          None
# 1          무제한      0~18   청소년        None         None          None
#
#                                                                        AI_SHORT_DESC
# 0  만 34세 이하 고객에게 합리적인 가격으로 데이터 걱정을 덜어주는 '청년 맞춤 실속...
# 1  만 18세 이하 학생들을 위해 넉넉한 20GB 데이터를 제공하는 합리적인 5G 전용...

# %% [markdown]
# # 테이블 조회

# %%
try:
    # 1. 테이블 목록 조회 쿼리
    table_list_query = "SHOW TABLES"
    tables = pd.read_sql(table_list_query, engine)
    
    print("--- 현재 접속 가능한 테이블 목록 ---")
    print(tables)
    
except Exception as e:
    print(f"조회 에러: {e}")
# Out:
# --- 현재 접속 가능한 테이블 목록 ---
#     Tables_in_telecom_media
# 0        mpr_5g_nw_qty_calc
# 1        mpr_5g_nw_qty_comp
# 2        mpr_5g_nw_qty_info
# 3               mpr_comm_cd
# 4       mpr_lte_nw_qty_calc
# ..                      ...
# 61             tb_user_info
# 62  tb_user_join_apply_info
# 63      tb_widget_auth_info
# 64           tb_widget_info
# 65     tb_widget_query_info
#
# [66 rows x 1 columns]

# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib.parse

DB_HOST = "192.168.5.102"
DB_PORT = "3306"
DB_USER = "ktoa"
DB_PASSWORD = "ktoa#1234"

safe_password = urllib.parse.quote_plus(DB_PASSWORD)

# DB_NAME을 제외하고 연결 (서버 자체에 접속)
connection_url = f"mysql+pymysql://{DB_USER}:{safe_password}@{DB_HOST}:{DB_PORT}/"
engine = create_engine(connection_url)

try:
    # 현재 계정으로 접근 가능한 DB 목록 조회
    df_dbs = pd.read_sql("SHOW DATABASES", engine)
    print("접근 가능한 데이터베이스 목록:")
    print(df_dbs)
except Exception as e:
    print(f"접근 실패: {e}")
# Out:
# 접근 가능한 데이터베이스 목록:
#              Database
# 0  information_schema
# 1             misobot
# 2       telecom_media
# 3   telecom_media_new
# 4                test

# %% [markdown]
# ## 저장

# %%
pip install openpyxl
# Out:
# ...
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
# 엑셀로 저장 (openpyxl 설치 필요)
df.to_excel(r"C:\Users\미소정보기술\OneDrive - 인하대학교\바탕 화면\RAG\data\KT.xlsx", index=False)

# CSV로 저장
df.to_csv(r"C:\Users\미소정보기술\OneDrive - 인하대학교\바탕 화면\RAG\data\KT.csv", index=False, encoding='utf-8-sig')
